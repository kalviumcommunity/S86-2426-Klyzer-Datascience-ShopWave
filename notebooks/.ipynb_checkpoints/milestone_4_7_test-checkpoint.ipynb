# %% [markdown]
# # Milestone 4.7 - Jupyter Notebook Verification
#
# This notebook demonstrates successful Jupyter setup and navigation.
#
# **Purpose:** Verify that Jupyter Notebook is working correctly in the project environment.

# %%
# Test Cell 1: Verify Python is working
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

# %%
# Test Cell 2: Basic operations
numbers = [1, 2, 3, 4, 5]
sum_numbers = sum(numbers)
print(f"Sum of {numbers} = {sum_numbers}")
print("✓ Jupyter Notebook is working correctly!")

# %%
# Test Cell 3: Import common libraries
try:
    import pandas as pd
    import numpy as np
    print("✓ pandas version:", pd.__version__)
    print("✓ numpy version:", np.__version__)
except ImportError as e:
    print(f"⚠ Library not installed: {e}")

# %% [markdown]
# ## Notebook Management Test
#
# This section confirms you can:
# - Run cells successfully
# - See output properly
# - Navigate the notebook interface
#
# **Next Steps:**
# 1. Save this notebook (Ctrl+S or Cmd+S)
# 2. Rename it if needed
# 3. Close and reopen it from the Home interface

# %%
# Test Cell 4: File location verification
import os
print(f"Current working directory: {os.getcwd()}")
print(f"Notebook is running from: {os.path.basename(os.getcwd())}")
